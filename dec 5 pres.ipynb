# %%
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# Adding text to plotting  Matplotlib can be done through a variety of commands. You can change the height of your graph with the fig.subplots_adjust command, and changing the top value to your desired scale. Use the ax.axis([]) command.

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=.85)
ax.axis([0, 10, 0, 10])
# Out:
# (0.0, 10.0, 0.0, 10.0)

# %% [markdown]
# You can add a chart title with the fig.suptitle command and customize the font size and weight, and axis titles and labels with ax.set_ command.

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=.85)
ax.axis([0, 10, 0, 10])

fig.suptitle('chart title', fontsize=14, fontweight='bold')
ax.set_title('axes title')
ax.set_xlabel('x axis label', fontsize=12)
ax.set_ylabel('y axis label', fontsize=12)
# Out:
# Text(0, 0.5, 'y axis label')

# %% [markdown]
# There are lots of fun additions you can make to your chart or graph using some simple commands from matplotlib. You can add a color fill to a piece of boxed text, and you can even change the font style. Designate values to 'alpha' for the opacity of the colorfill and 'pad' for the amount of space around teh text to be enclosed in the box. You can add other text lines inside your chart or graph in specific places using the coordinates of the place you would like inside the ax.text() command. If there is not a specific coordinate you would like you text in, you can simply write the position within the chart where you would like the text. Finally, you can create and annotate a point with text or symbols like arrows. Notice specific syntax and indentation needed for each command. the dict() function can determine the color of the symbol along with the space between the point and the symbol.

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)
ax.axis([0, 10, 0, 10])

fig.suptitle('chart title', fontsize=14, fontweight='bold')
ax.set_title('axes title')
ax.set_xlabel('x axis label', fontsize=12)
ax.set_ylabel('y axis label', fontsize=12)

ax.text(3, 8, 'boxed text', style='italic',
        bbox={'facecolor': 'pink', 'alpha': .9, 'pad': 12})

ax.text(2, 6, r'an equation: $E=mc^2$', fontsize=15)

ax.text(3, 2, 'text inside graph')

ax.text(0.95, 0.01, 'colored text inside graph',
        verticalalignment='bottom', horizontalalignment='right',
        transform=ax.transAxes,
        color='purple', fontsize=15)

ax.plot([2], [1], 'o')
ax.annotate('annotate a point', xy=(2, 1), xytext=(3, 4),
            arrowprops=dict(facecolor='blue', shrink=0.06))
plt.show()

# %% [markdown]
# The positions of the x and y axes can be shifted, too,  using the labelpad function. In this example, we shifted the y axis label further left from the graph, and the x axis further down from the graph. If we want to shift the label to the right or left, we need to input a specific point.

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)
ax.axis([0, 10, 0, 10])

fig.suptitle('chart title', fontsize=14, fontweight='bold')
ax.set_title('axes title')
ax.set_xlabel('x axis label', fontsize=15)
ax.set_ylabel('y axis label', fontsize=15)


ax.set_xlabel('x axis label', labelpad=20, position=(0., 1e6), horizontalalignment='left')
ax.set_ylabel('y axis label]', labelpad=20)
plt.show()

# %% [markdown]
# You can also change the font with matplotlib!

# %%
fig = plt.figure()
ax = fig.add_subplot()
fig.subplots_adjust(top=0.85)
ax.axis([0, 10, 0, 10])

fig.suptitle('chart title', fontsize=14, fontweight='bold')
ax.set_title('axes title')
ax.set_xlabel('x axis label', fontsize=14)
ax.set_ylabel('y axis label', fontsize=14)

ax.set_xlabel('x axis label', labelpad=20, position=(0., 1e6), horizontalalignment='left')
ax.set_ylabel('y axis label]', labelpad=20)

from matplotlib.font_manager import FontProperties
font = FontProperties()
font.set_family('serif')
font.set_name('Times New Roman')
font.set_style('italic')


plt.show()

# %% [markdown]
# We can change the position (vertically and horizontally) of chart titles, also, using the loc argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.linspace(0.0, 5.0, 100)
y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)

fig, ax = plt.subplots(figsize=(5, 3))
fig.subplots_adjust(bottom=0.15, left=0.2)
ax.plot(x1, y1)

fig, axs = plt.subplots(3, 1, figsize=(5, 6), tight_layout=True)
locs = ['center', 'left', 'right']
for ax, loc in zip(axs, locs):
    ax.plot(x1, y1)
    ax.set_title('Title with loc at '+loc, loc=loc)
plt.show()

# %% [markdown]
# Just like text in graphs, we can use the pad function to change the vertical position of titles.

# %%
fig, ax = plt.subplots(figsize=(5, 3))
fig.subplots_adjust(top=0.8)
ax.plot(x1, y1)
ax.set_title('Vertically offset title', pad=30)
plt.show()

# %% [markdown]
# Now, we will cover how to input changes to your tick marks on a chart or graph. We can change the value of the x-axis tick marks from the default setting using the set_ticks argument

# %%
import matplotlib.pyplot as plt
import numpy as np

fig, axs = plt.subplots(2, 1, figsize=(5, 3), tight_layout=True)
axs[0].plot(x1, y1)
axs[1].plot(x1, y1)
axs[1].xaxis.set_ticks(np.arange(0., 8.1, 2.))
plt.show()

# %% [markdown]
# We can also use list comprehensions to change the tick labels.

# %%
fig, axs = plt.subplots(2, 1, figsize=(5, 3), tight_layout=True)
axs[0].plot(x1, y1)
axs[1].plot(x1, y1)
ticks = np.arange(0., 8.1, 2.)

tickla = [f'{tick:1.2f}' for tick in ticks]
axs[1].xaxis.set_ticks(ticks)
axs[1].xaxis.set_ticklabels(tickla)
axs[1].set_xlim(axs[0].get_xlim())
plt.show()

# %% [markdown]
# Instead of making a list of all of the ticklabels, though, we could use strings to dictate the ticks along with the amount of decimal points wanted.

# %%
fig, axs = plt.subplots(2, 1, figsize=(5, 3), tight_layout=True)
axs[0].plot(x1, y1)
axs[1].plot(x1, y1)
ticks = np.arange(0., 8.1, 2.)
axs[1].xaxis.set_ticks(ticks)
axs[1].xaxis.set_major_formatter('{x:1.1f}')
axs[1].set_xlim(axs[0].get_xlim())
plt.show()

# %% [markdown]
# Continuing with ticks, we can move ticks from their default position on the bottom of the x axis...

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)

# %% [markdown]
# To the top of the x axis with the ax.tick_params argument.

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)


ax.tick_params(bottom=False, top=True, left=True, right=True)
ax.tick_params(labelbottom=False, labeltop=True, labelleft=True, labelright=True)

# %% [markdown]
# import matplotlib
# matplotlib.use("agg")
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(1, 13, 500)
# y = 1 + np.sinc(x - 7)
# fig = plt.figure()
# ax = fig.gca()
# ax.plot(x, y)ax.tick_params also can change the direction of the tick marks.

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)

ax.tick_params(axis="x", direction="in")
ax.tick_params(axis="y", direction="inout")

# %% [markdown]
# If you want your ticks in different colors, tick_params can also do that!

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)


ax.tick_params(axis="x", direction="out", length=16, width=2, color="red")
ax.tick_params(axis="y", direction="out", length=6, width=4, color="green")

# %% [markdown]
# Tick labels can also be styalized to your liking.

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)

ax.tick_params(axis="x", labelsize=12, labelrotation=-20, labelcolor="turquoise")
ax.tick_params(axis="y", labelsize=12, labelrotation=20, labelcolor="orange")

# %% [markdown]
# Finally we can add a grid to our graph to make our tick marks line up more preceisely to the eye at our desired points.

# %%
import matplotlib
matplotlib.use("agg")
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(1, 13, 500)
y = 1 + np.sinc(x - 7)
fig = plt.figure()
ax = fig.gca()
ax.plot(x, y)

ax.grid(axis="x", color="green", alpha=.9, linewidth=2, linestyle=":")
ax.grid(axis="y", color="black", alpha=.8, linewidth=.5)

# %% [markdown]
# Our last section will be about adding text at a general position rather than at a specific point. To do this, we can use the ax.transAxes function.

# %%
def add_mean_line(data):
    mu = np.mean(data)
    
    ax=plt.gca()
    ax.axvline(mu, color='black', lw=3, ls='--') 
    ax.text(0.7, 0.9, f'mean={mu:.2f}',
            transform=ax.transAxes,
            fontweight='bold', fontsize=12)

# %%
    
values = np.random.normal(10, 2, size=100)
    
plt.hist(values, color='lightblue')
add_mean_line(values);

# %% [markdown]
# Finally, we can add text to variables using loops.

# %%
students = ['A', 'B', 'C', 'D', 'E']
grades = [80, 42, 68, 91, 77]

plt.bar(students, grades, edgecolor='black', color='xkcd:light gray blue')

for i, g in enumerate(grades):
    plt.text(i, g-8, f' {g} ', ha='center', fontsize=16)
    
plt.xlabel('Student')
# Out:
# Text(0.5, 0, 'Student')

# %% [markdown]
# Practice problems:

# %% [markdown]
# Try to create a graph with decimal variables instead of a single interger on the x axis.

# %% [markdown]
# Insert text on a graph with a blue box around it, and annotate a purple point with a green arrow.
